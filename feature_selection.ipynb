# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/bigten_data_clean_ml.csv')

# %%
df
# Out:
#      game_id  Playoffs  Home_opponent-effective-possession-ratio  \
# 0          0         0                                     0.949
# 1          1         0                                     0.932
# 2          2         0                                     0.914
# 3          4         0                                     0.962
# 4          5         0                                     0.916
# ..       ...       ...                                       ...
# 699      716         1                                     0.984
# 700      717         1                                     0.940
# 701      718         1                                     0.938
# 702      719         1                                     0.958
# 703      720         1                                     0.937
#
#      Home_opponent-effective-possession-ratio_last1  \
# 0                                             0.873
# 1                                             0.807
# ...

# %%
X_columns = [col for col in df.columns if col not in ['game_id', 'Playoffs', 'OT', 'Tot', 'Spread', 'winner']]
X_df = df[X_columns]
X_df.head()
# Out:
#    Home_opponent-effective-possession-ratio  \
# 0                                     0.949
# 1                                     0.932
# 2                                     0.914
# 3                                     0.962
# 4                                     0.916
#
#    Home_opponent-effective-possession-ratio_last1  \
# 0                                           0.873
# 1                                           0.807
# 2                                           0.847
# 3                                           0.861
# 4                                           0.838
#
#    Home_opponent-effective-possession-ratio_last3  \
# 0                                           0.916
# 1                                           0.864
# 2                                           0.921
# 3                                           0.940
# 4                                           0.903
#
#    Home_opponent-effective-possession-ratio_home  \
# ...

# %%
y_columns = ['winner']
y_df = df[y_columns]

# %% [markdown]
# ### Sklearn

# %%
# Feature Selection with Univariate Statistical Tests
from pandas import read_csv
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
# load data
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
test = SelectKBest(score_func=f_classif, k=4)
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:5,:])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-159276123538> in <module>
#       7 filename = 'pima-indians-diabetes.data.csv'
#       8 names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
# ----> 9 dataframe = read_csv(filename, names=names)
#      10 array = dataframe.values
#      11 X = array[:,0:8]
#
# ...

# %% [markdown]
# ## RFE

# %%
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# load data
X = X_df.values
Y = y_df.values
# feature extraction
model = LogisticRegression(solver='lbfgs')
rfe = RFE(model, 5)
fit = rfe.fit(X, Y)
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=3 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
X_df.loc[:, list(fit.support_)]
# Out:
#      Home_team-rebounds-per-game_last3  Away_blocks-per-game  \
# 0                                  1.7                   2.5
# 1                                  5.3                   5.4
# 2                                  3.7                   6.9
# 3                                  2.3                   4.2
# 4                                  1.0                   4.1
# ..                                 ...                   ...
# 699                                2.0                   3.8
# 700                                3.3                   3.3
# 701                                2.7                   4.6
# 702                                1.0                   3.3
# 703                                3.0                   3.4
#
#      Away_steals-per-game_home
# 0                          5.6
# 1                          5.9
# 2                          5.7
# 3                          6.2
# 4                          7.6
# ..                         ...
# ...

# %%
df[(df.Home_ML < 0) & (df.winner == 1)].shape[0] / df.shape[0]
# Out:
# 0.5326704545454546

# %%
# Feature Importance with Extra Trees Classifier
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier

X = X_df.values
Y = y_df.values
# feature extraction
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
print(model.feature_importances_)
# Out:
# [0.    0.001 0.001 ... 0.    0.001 0.001]
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':

# %%
df[(df.Home == 'Purdue')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-99a699aec2e8> in <module>
# ----> 1 df[(df.Home == 'Purdue')]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Home'

# %%
df
# Out:
#      game_id  Playoffs  Home_opponent-effective-possession-ratio  \
# 0          0         0                                     0.949
# 1          1         0                                     0.932
# 2          2         0                                     0.914
# 3          4         0                                     0.962
# 4          5         0                                     0.916
# ..       ...       ...                                       ...
# 699      716         1                                     0.984
# 700      717         1                                     0.940
# 701      718         1                                     0.938
# 702      719         1                                     0.958
# 703      720         1                                     0.937
#
#      Home_opponent-effective-possession-ratio_last1  \
# 0                                             0.873
# 1                                             0.807
# ...

# %%
df_all = pd.read_csv('data/bigten_data_joined.csv')

# %%
cols = list(df_all.columns[0:5]) + ['winner'] + ['Home_win-pct-all-games', 'Away_win-pct-all-games']

# %%
criteria = list((df_all.Home == "Purdue").values) or list((df_all.Away == "Purdue").values)

# %%
df1 = df_all[(df_all.Away=='Purdue') & (df_all.season_num==5)][cols]
df2 = df_all[(df_all.Home=='Purdue') & (df_all.season_num==5)][cols]
df_pur = pd.concat([df1, df2]).sort_values('Date')
df_pur
# Out:
#      game_id        Date            Home  Home_PTS            Away  winner  \
# 575      575  2020-12-16          Purdue        67      Ohio State       1
# 578      578  2020-12-22            Iowa        70          Purdue       1
# 586      586  2020-12-25          Purdue        73        Maryland       1
# 592      592  2020-12-29         Rutgers        81          Purdue       1
# 597      597  2021-01-02        Illinois        66          Purdue       1
# 608      608  2021-01-08  Michigan State        54          Purdue       0
# 615      615  2021-01-14         Indiana        69          Purdue       0
# 620      620  2021-01-17          Purdue        80      Penn State       1
# 623      623  2021-01-19      Ohio State        65          Purdue       0
# 627      627  2021-01-22          Purdue        53        Michigan       0
# 637      637  2021-01-30          Purdue        81       Minnesota       1
# ...

# %%
[x for x in df_all.columns if 'win' in x]
# Out:
# ['Home_win-pct-all-games',
#  'Home_win-pct-all-games_last1',
#  'Home_win-pct-all-games_last3',
#  'Home_win-pct-all-games_home',
#  'Home_win-pct-all-games_away',
#  'Away_win-pct-all-games',
#  'Away_win-pct-all-games_last1',
#  'Away_win-pct-all-games_last3',
#  'Away_win-pct-all-games_home',
#  'Away_win-pct-all-games_away',
#  'Home_opponent-win-pct-all-games',
#  'Home_opponent-win-pct-all-games_last1',
#  'Home_opponent-win-pct-all-games_last3',
#  'Home_opponent-win-pct-all-games_home',
#  'Home_opponent-win-pct-all-games_away',
#  'Away_opponent-win-pct-all-games',
#  'Away_opponent-win-pct-all-games_last1',
#  'Away_opponent-win-pct-all-games_last3',
#  'Away_opponent-win-pct-all-games_home',
#  'Away_opponent-win-pct-all-games_away',
#  'Home_win-pct-close-games',
#  'Home_win-pct-close-games_last1',
#  'Home_win-pct-close-games_last3',
#  'Home_win-pct-close-games_home',
#  'Home_win-pct-close-games_away',
#  'Away_win-pct-close-games',
# ...
