# %%
import pandas as pd
import numpy as np
import requests

# %%
df = pd.read_csv('data/bigten_data_w_links.csv', index_col='Unnamed: 0')
df
# Out:
#        G        Date  season_end    Type       TEAM                Opponent  \
# 0      1  2009-11-13        2010     REG    Indiana                  Howard
# 1      2  2009-11-16        2010     REG    Indiana  South Carolina Upstate
# 2      3  2009-11-19        2010     REG    Indiana             Mississippi
# 3      4  2009-11-20        2010     REG    Indiana       Boston University
# 4      5  2009-11-22        2010     REG    Indiana            George Mason
# ...   ..         ...         ...     ...        ...                     ...
# 5617  27  2021-03-07        2021     REG  Wisconsin                    Iowa
# 5618  28  2021-03-11        2021  CTOURN  Wisconsin              Penn State
# 5619  29  2021-03-12        2021  CTOURN  Wisconsin                    Iowa
# 5620  30  2021-03-19        2021    NCAA  Wisconsin          North Carolina
# 5621  31  2021-03-21        2021    NCAA  Wisconsin                  Baylor
#
#          Conf  Tm  Opp    Won   OT   W   L Streak  \
# ...

# %%
df.at[5392, 'link'] = 'https://www.sports-reference.com/cbb/boxscores/2014-12-22-california.html'

# %%
df[df.link=='-1']
# Out:
#        G        Date  season_end    Type        TEAM    Opponent     Conf  Tm  \
# 1672  34  2010-03-14        2010  CTOURN  Ohio State   Minnesota  Big Ten  90
# 3661  34  2010-03-14        2010  CTOURN   Minnesota  Ohio State  Big Ten  61
#
#       Opp    Won   OT   W   L Streak               Arena  game_id link
# 1672   61   True  NaN  27   7    W 7  Conseco Fieldhouse     1565   -1
# 3661   90  False  NaN  21  13    L 1  Conseco Fieldhouse     1565   -1

# %%
df.to_csv('data/bigten_data_w_links.csv')

# %%
df2 = pd.read_csv('data/bigten_data_w_links.csv')

# %%
df2[df2.link=='-1']
# Out:
#       Unnamed: 0   G        Date  season_end    Type        TEAM    Opponent  \
# 1672        1672  34  2010-03-14        2010  CTOURN  Ohio State   Minnesota
# 3661        3661  34  2010-03-14        2010  CTOURN   Minnesota  Ohio State
#
#          Conf  Tm  Opp    Won   OT   W   L Streak               Arena  \
# 1672  Big Ten  90   61   True  NaN  27   7    W 7  Conseco Fieldhouse
# 3661  Big Ten  61   90  False  NaN  21  13    L 1  Conseco Fieldhouse
#
#       game_id link
# 1672     1565   -1
# 3661     1565   -1

# %%
set(df.TEAM)
# Out:
# {'Illinois',
#  'Indiana',
#  'Iowa',
#  'Maryland',
#  'Michigan',
#  'Michigan State',
#  'Minnesota',
#  'Nebraska',
#  'Northwestern',
#  'Ohio State',
#  'Penn State',
#  'Purdue',
#  'Rutgers',
#  'Wisconsin'}
